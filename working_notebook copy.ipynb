# %%
from train_img_unet2d_ms import Dataset, aera1d_conv
import torch
import matplotlib.pyplot as plt

# %%
target = torch.load('/home/peter/data/2dmap/716.pt')[:32, :]
plt.figure()
plt.imshow(target)
print(target.shape)
# Out:
# torch.Size([32, 1025])

# %%
target = torch.load('/home/peter/data/2dmap/716.pt')[:32, :]
target = aera1d_conv(target, 4, stride=4)
plt.figure()
plt.imshow(target)
print(target.shape)
# Out:
# torch.Size([8, 256])
# /home/ismail/lung-2d/train_img_unet2d_ms.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   output = torch.nn.functional.conv2d(torch.tensor(temp_p).unsqueeze(0).unsqueeze(0) ,weight.unsqueeze(0).unsqueeze(0), stride=stride,padding=max(cur_l//2-1, 0))

# %%
target_hres = aera1d_conv(target, 2, stride=2)
# Out:
# /home/ismail/lung-2d/train_img_unet2d_ms.py:55: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   output = torch.nn.functional.conv2d(torch.tensor(temp_p).unsqueeze(0).unsqueeze(0) ,weight.unsqueeze(0).unsqueeze(0), stride=stride,padding=max(cur_l//2-1, 0))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 target_hres = aera1d_conv(target, 2, stride=2)
#
# File ~/lung-2d/train_img_unet2d_ms.py:55, in aera1d_conv(temp_p, cur_l, stride)
#      53     output = torch.nn.functional.conv2d(torch.tensor(temp_p).unsqueeze(0).unsqueeze(0) ,weight.unsqueeze(0).unsqueeze(0), stride=cur_l)
#      54 else:
# ...

# %%
target = torch.load('results/sample_output_18.pt')
target = target.cpu()
plt.figure()
plt.imshow(target[0])
